# %%
import sys

sys.path.append('/Users/leportella/src/serenata/medidor-de-poder/api/candidates')

from decouple import config
from datetime import datetime
import pandas as pd
import mongoengine as me

from models.elections import ElectionsCount
from models import Candidates

me.connect(host=config('MONGO_URL'))
# Out:
# MongoClient(host=['cluster0-shard-00-02-1wqt1.mongodb.net:27017', 'cluster0-shard-00-00-1wqt1.mongodb.net:27017', 'cluster0-shard-00-01-1wqt1.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='Cluster0-shard-0', authsource='admin', retrywrites=True, read_preference=Primary())

# %%
tse_candidates = pd.read_csv('../data/2017-07-20-tse-candidates.xz', low_memory=False, dtype={'cpf': str})
tse_candidates.head()
# Out:
#    year  phase    description state    location        post  \
# 0  2004      1  ELEICOES 2004    AC  ACRELANDIA       mayor
# 1  2004      1  ELEICOES 2004    AC  ACRELANDIA       mayor
# 2  2004      1  ELEICOES 2004    AC  ACRELANDIA       mayor
# 3  2004      1  ELEICOES 2004    AC  ACRELANDIA  vice_mayor
# 4  2004      1  ELEICOES 2004    AC  ACRELANDIA  vice_mayor
#
#                              name  electoral_id          cpf      voter_id  \
# 0                 JOÃO DE ALMEIDA             6  18139124249  000356682496
# 1  PAULO CÉSAR FERREIRA DE ARAUJO             1  07857136204  000525772445
# 2     SEBASTIÃO BOCALOM RODRIGUES            27  17357152987  002053882488
# 3        ERAIDES CAETANO DE SOUZA             7  40917860900  002817512496
# 4     RICARDO MODESTO DE OLIVEIRA             2  61109029268  002600402445
#
#         result
# 0  not_elected
# 1  not_elected
# 2      elected
# 3          NaN
# 4          NaN

# %% [markdown]
# ## Count elections result per candidate

# %%
dd = tse_candidates.groupby(['cpf', 'result'])['result'].count()

# %%
elections = dd.unstack()
elections.head()
# Out:
# result       alternate  elected  elected_by_party_quota  not_elected  \
# cpf
# #NULO#           249.0     57.0                     NaN        108.0
# 0                  2.0      1.0                     NaN          NaN
# 00000000000        4.0      NaN                     NaN          4.0
# 00000012017        1.0      NaN                     NaN          NaN
# 00000165000        1.0      NaN                     NaN          NaN
#
# result       rejected  replaced  runoff
# cpf
# #NULO#            7.0       1.0     NaN
# 0                 NaN       NaN     NaN
# 00000000000       1.0       NaN     NaN
# 00000012017       NaN       NaN     NaN
# 00000165000       NaN       NaN     NaN

# %% [markdown]
# ## Get personal information of all candidates

# %%
candidates = tse_candidates.drop_duplicates(subset='cpf')[['name', 'cpf', 'voter_id', 'state']]
candidates.rename(columns={'name': 'civil_name'})
candidates.head()
# Out:
#                              name          cpf      voter_id state
# 0                 JOÃO DE ALMEIDA  18139124249  000356682496    AC
# 1  PAULO CÉSAR FERREIRA DE ARAUJO  07857136204  000525772445    AC
# 2     SEBASTIÃO BOCALOM RODRIGUES  17357152987  002053882488    AC
# 3        ERAIDES CAETANO DE SOUZA  40917860900  002817512496    AC
# 4     RICARDO MODESTO DE OLIVEIRA  61109029268  002600402445    AC

# %%
candidates_elections = pd.merge(candidates, elections, on='cpf')
candidates_elections.head()
# Out:
#                              name          cpf      voter_id state  alternate  \
# 0                 JOÃO DE ALMEIDA  18139124249  000356682496    AC        NaN
# 1  PAULO CÉSAR FERREIRA DE ARAUJO  07857136204  000525772445    AC        NaN
# 2     SEBASTIÃO BOCALOM RODRIGUES  17357152987  002053882488    AC        NaN
# 3     RICARDO MODESTO DE OLIVEIRA  61109029268  002600402445    AC        1.0
# 4        VILSEU FERREIRA DA SILVA  27278913187  000411782470    AC        NaN
#
#    elected  elected_by_party_quota  not_elected  rejected  replaced  runoff
# 0      NaN                     NaN          1.0       NaN       NaN     NaN
# 1      NaN                     NaN          1.0       NaN       NaN     NaN
# 2      1.0                     NaN          5.0       NaN       NaN     1.0
# 3      NaN                     NaN          NaN       NaN       NaN     NaN
# 4      1.0                     NaN          NaN       1.0       NaN     NaN

# %%
# Rename columsn of number of elections by status to elections_status
# Ex:  elected to elections_elected

for col in elections.columns.values:
    candidates_elections.rename(columns={col: 'elections_{}'.format(col)}, inplace=True)

# %%
candidates_elections.head(2)
# Out:
#                              name          cpf      voter_id state  \
# 0                 JOÃO DE ALMEIDA  18139124249  000356682496    AC
# 1  PAULO CÉSAR FERREIRA DE ARAUJO  07857136204  000525772445    AC
#
#    elections_alternate  elections_elected  elections_elected_by_party_quota  \
# 0                  NaN                NaN                               NaN
# 1                  NaN                NaN                               NaN
#
#    elections_not_elected  elections_rejected  elections_replaced  \
# 0                    1.0                 NaN                 NaN
# 1                    1.0                 NaN                 NaN
#
#    elections_runoff
# 0               NaN
# 1               NaN

# %% [markdown]
# ## Get type of elections won
#
# Gets how many times the candidate was elected or elected by party quota to each available post

# %%
elected_candidates = tse_candidates[tse_candidates.result.isin(['elected', 'elected_by_party_quota'])]
num_election_won = elected_candidates.groupby(['cpf', 'post'])['result'].count()
num_election_won = num_election_won.unstack()
num_election_won.head()
# Out:
# post         city_councilman  district_deputy  federal_deputy  governor  \
# cpf
# #NULO#                  54.0              NaN             NaN       NaN
# 0                        1.0              NaN             NaN       NaN
# 00000602590              1.0              NaN             NaN       NaN
# 00000634107              1.0              NaN             NaN       NaN
# 00000866571              1.0              NaN             NaN       NaN
#
# post         mayor  president  senate_first_alternate  \
# cpf
# #NULO#         1.0        NaN                     NaN
# 0              NaN        NaN                     NaN
# 00000602590    NaN        NaN                     NaN
# 00000634107    NaN        NaN                     NaN
# 00000866571    NaN        NaN                     NaN
#
# post         senate_second_alternate  senator  state_deputy  vice_governor  \
# cpf
# #NULO#                           NaN      NaN           NaN            NaN
# 0                                NaN      NaN           NaN            NaN
# 00000602590                      NaN      NaN           NaN            NaN
# 00000634107                      NaN      NaN           NaN            NaN
# 00000866571                      NaN      NaN           NaN            NaN
#
# post         vice_mayor  vice_president
# cpf
# #NULO#              NaN             NaN
# 0                   NaN             NaN
# 00000602590         NaN             NaN
# 00000634107         NaN             NaN
# 00000866571         NaN             NaN

# %%
candidates_elections = pd.merge(candidates_elections, num_election_won, on='cpf')

# %%
for col in num_election_won.columns.values:
    candidates_elections.rename(columns={col: 'times_elected_to_{}'.format(col)}, inplace=True)

# %%
candidates_elections.shape
# Out:
# (167024, 24)

# %%
candidates_elections.rename(columns={'name': 'civil_name'}, inplace=True)
candidates_elections.to_csv('../data/datalake/candidates_elections.csv', index=False)

# %%
candidates_elections.head()
# Out:
#                      civil_name          cpf      voter_id state  \
# 0   SEBASTIÃO BOCALOM RODRIGUES  17357152987  002053882488    AC
# 1      VILSEU FERREIRA DA SILVA  27278913187  000411782470    AC
# 2       ARISTON DE SOUZA JARDIM  52024768253  003552582461    AC
# 3  CARLOS CÉSAR NUNES DE ARAÚJO  73900443220  003851432453    AC
# 4           DAMARIS DE OLIVEIRA  49488929200  000968162410    AC
#
#    elections_alternate  elections_elected  elections_elected_by_party_quota  \
# 0                  NaN                1.0                               NaN
# 1                  NaN                1.0                               NaN
# 2                  1.0                NaN                               1.0
# 3                  1.0                1.0                               NaN
# 4                  NaN                1.0                               NaN
#
#    elections_not_elected  elections_rejected  elections_replaced  \
# 0                    5.0                 NaN                 NaN
# 1                    NaN                 1.0                 NaN
# 2                    1.0                 NaN                 NaN
# 3                    1.0                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
#
#                 ...                 times_elected_to_governor  \
# 0               ...                                       NaN
# 1               ...                                       NaN
# 2               ...                                       NaN
# 3               ...                                       NaN
# 4               ...                                       NaN
#
#    times_elected_to_mayor  times_elected_to_president  \
# 0                     1.0                         NaN
# 1                     1.0                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    times_elected_to_senate_first_alternate  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    times_elected_to_senate_second_alternate  times_elected_to_senator  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
#
#    times_elected_to_state_deputy  times_elected_to_vice_governor  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    times_elected_to_vice_mayor  times_elected_to_vice_president
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
#
# [5 rows x 24 columns]

# %%
candidates_elections.iloc[0]
# Out:
# civil_name                                  SEBASTIÃO BOCALOM RODRIGUES
# cpf                                                         17357152987
# voter_id                                                   002053882488
# state                                                                AC
# elections_alternate                                                 NaN
# elections_elected                                                     1
# elections_elected_by_party_quota                                    NaN
# elections_not_elected                                                 5
# elections_rejected                                                  NaN
# elections_replaced                                                  NaN
# elections_runoff                                                      1
# times_elected_to_city_councilman                                    NaN
# times_elected_to_district_deputy                                    NaN
# times_elected_to_federal_deputy                                     NaN
# times_elected_to_governor                                           NaN
# times_elected_to_mayor                                                1
# times_elected_to_president                                          NaN
# times_elected_to_senate_first_alternate                             NaN
# times_elected_to_senate_second_alternate                            NaN
# times_elected_to_senator                                            NaN
# times_elected_to_state_deputy                                       NaN
# times_elected_to_vice_governor                                      NaN
# times_elected_to_vice_mayor                                         NaN
# times_elected_to_vice_president                                     NaN
# Name: 0, dtype: object

# %%
def add_dict_to_instance(instance, infos):
    for key in infos:
        setattr(instance, key, infos[key])
    return instance

# %%
items = [
    'elections_alternate',
    'elections_elected', 
    'elections_elected_by_party_quota',
    'elections_not_elected', 
    'elections_rejected', 
    'elections_replaced',
    'elections_runoff', 
    'times_elected_to_city_councilman',
    'times_elected_to_district_deputy', 
    'times_elected_to_federal_deputy',
    'times_elected_to_governor', 
    'times_elected_to_mayor',
    'times_elected_to_president', 
    'times_elected_to_senate_first_alternate',
    'times_elected_to_senate_second_alternate', 
    'times_elected_to_senator',
    'times_elected_to_state_deputy', 
    'times_elected_to_vice_governor',
    'times_elected_to_vice_mayor', 
    'times_elected_to_vice_president'
]

def get_elections_count_dict(row):
    row = row.fillna(0)
    info = row[items].to_dict()
    return {key: info.get(key) for key in info if info.get(key)}

# %% [markdown]
# # Add info to mongodb

# %%
for i, row in candidates_elections.iterrows():
    try:
        Candidates.objects.get(cpf=row['cpf'])
        print('Found')
    except :
        elections_count = get_elections_count_dict(row)

        print('Added: ', row['cpf'])
        c = Candidates(
            cpf=row['cpf'],
            civil_name=row['civil_name'],
            voter_id=row['voter_id'],
            state=row['state'],
        )
        c.elections_count = add_dict_to_instance(ElectionsCount(), elections_count)
        c.elections_count.save()
        c.save()
# Out:
# Added:  17357152987
